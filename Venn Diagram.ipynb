# %%
pip install matplotlib matplotlib-venn

# %%
import matplotlib.pyplot as plt
from matplotlib_venn import venn3, venn3_circles

# Lists renamed as MOFA, Single-Omics, and RGCCA
MOFA = [
    'genus_Bilophila', 'genus_Parasutterella', 'order_Burkholderiales',
    'class_Betaproteobacteria', 'family_Sutterellaceae', 'family_Desulfovibrionaceae',
    'order_Desulfovibrionales', 'class_Deltaproteobacteria', 'family_Coriobacteriaceae',
    'order_Coriobacteriales', 'class_Actinobacteria', 'phylum_Actinobacteria',
    'genus_Collinsella', 'genus_Oscillibacter', 'family_Rikenellaceae', 'genus_Alistipes',
    'genus_unclassified_Ruminococcaceae', 'genus_Erysipelotrichaceae_incertae_sedis',
    'genus_Clostridium.XlVb', 'genus_Prevotella'
]

MixOmics = [
    "genus_unclassified_Lachnospiraceae",
    "phylum_unclassified_Bacteria",
    "class_unclassified_Bacteria",
    "order_unclassified_Bacteria",
    "family_unclassified_Bacteria",
    "genus_unclassified_Bacteria",
    "genus_Ruminococcus",
    "genus_Odoribacter",
    "genus_Blautia",
    "genus_Clostridium.XlVa",
    "genus_Clostridium.XlVb",
    "family_Clostridiaceae.1",
    "genus_Clostridium.sensu.stricto",
    "genus_Butyricicoccus",
    "family_unclassified_Clostridiales",
    "genus_unclassified_Clostridiales",
    "family_Rikenellaceae",
    "genus_Alistipes",
    "genus_Lachnospiracea_incertae_sedis",
    "genus_Collinsella"
]

RGCCA = [
    'phylum_Bacteroidetes', 'class_Bacteroidia', 'order_Bacteroidales',
    'phylum_Firmicutes', 'class_Clostridia', 'order_Clostridiales',
    'genus_Bacteroides', 'family_Bacteroidaceae', 'family_Ruminococcaceae',
    'genus_unclassified_Ruminococcaceae', 'class_Erysipelotrichia',
    'family_Erysipelotrichaceae', 'order_Erysipelotrichales',
    'genus_unclassified_Coriobacteriaceae', 'family_Lachnospiraceae',
    'family_Clostridiales_Incertae.Sedis.XIII', 'class_Actinobacteria',
    'phylum_Actinobacteria', 'family_Coriobacteriaceae', 'order_Coriobacteriales'
]

# Convert lists to sets
set_MOFA = set(MOFA)
set_MixOmics = set(MixOmics)
set_RGCCA = set(RGCCA)

# Create a Venn diagram
plt.figure(figsize=(12,10))
venn = venn3([set_MOFA, set_MixOmics, set_RGCCA],
             set_labels=('MOFA', 'MixOmics', 'RGCCA'),
             set_colors=('skyblue', 'lightgreen', 'lightcoral'),
             alpha=0.6)

# Add a border to the circles
venn3_circles([set_MOFA, set_MixOmics, set_RGCCA], linestyle='dashed')

# Annotate each section with the actual names (if needed)
for idx, subset in enumerate(venn.subset_labels):
    if subset:  # Only annotate non-empty subsets
        subset.set_fontsize(10)


# Display the diagram
plt.title('Venn Diagram top 20 features (candidate biomarkers) Microbiomics: MOFA vs MixOmics vs RGCCA')
plt.show()

# %%
import matplotlib.pyplot as plt
from matplotlib_venn import venn3, venn3_circles

# New lists
MOFA = [
    'MBL2', 'APOB', 'KV139', 'IGHM.1', 'MAP4', 'HV313', 'CPN2', 'HV333_2', 'LV211',
    'KV133', 'HV333', 'SHBG', 'CEP290', 'ALB', 'KV230', 'INPP5E', 'MMRN1', 'PRG4.1',
    'HV348', 'CD5L', 'CAPZB', 'FCN2', 'FCGBP', 'IGHG2', 'CFHR5', 'HV146', 'IGHM',
    'IGKC', 'CRISP3', 'IGF2', 'CTTNBP2', 'HBD', 'SERPINA5', 'F7', 'LV657_2', 'SLFN11',
    'IGFALS', 'IGHG3', 'ITIH2', 'MAP4', 'MYH7', 'EFEMP1', 'TGFBI', 'CFP', 'PGLYRP2',
    'PRDX2', 'MYBPC2', 'KV116', 'HRG', 'TF'
]

MixOmics = [
    'APOD', 'LPA', 'APOF', 'ADIPOQ', 'GSN', 'IL1RAP.1', 'IGHA2', 'F5',
    'CNDP1', 'F13A1', 'PON3', 'IL1RAP', 'APOA1', 'APOA4', 'C2', 'LRG1',
    'COLEC11', 'FBLN1', 'FBLN1.1', 'ECM1', 'SERPINA1', 'KV116', 'INHBC',
    'LV211', 'IGHM.1', 'NUP205', 'KV230', 'CEP290', 'HV330_2', 'CD5L',
    'HV146', 'LV319', 'HV169', 'SERPIND1', 'LV325', 'NPHP3', 'CFHR5',
    'LV743', 'LV144', 'KVD16', 'LV151', 'CFH', 'HV353', 'APOC4', 'IGHG2',
    'HP', 'IGJ', 'HV307_2', 'HV323', 'IGHM'
]


RGCCA = [
    'KVD16', 'CEP290', 'APOD', 'GPLD1', 'TGFBI', 'ATP5A1', 'KVD33_2', 'PIGR',
    'LV151', 'HV307_2', 'KRT17', 'LV657', 'GSN', 'FAM161B', 'PON3', 'MYBPC2',
    'MST1', 'CPN2', 'PF4', 'GAPDH', 'C1RL', 'NCAM1', 'ZNF10', 'PON1', 'GPX3',
    'SHBG', 'SERPINA6', 'FLNA', 'TTN', 'THBS1', 'MMRN1', 'KV116', 'OLFM1',
    'IGLL5', 'TFRC', 'HV169', 'PTPRC', 'CFI', 'F5', 'COMP', 'FRMPD1', 'IGHA1',

    'FBLN1', 'LUM', 'CST3', 'SELL', 'HV348', 'LRG1', 'CDK5RAP2', 'MBL2'
]
# Convert lists to sets
set_MOFA = set(MOFA)
set_MixOmics = set(MixOmics)
set_RGCCA = set(RGCCA)

# Create a Venn diagram
plt.figure(figsize=(12,10))
venn = venn3([set_MOFA, set_MixOmics, set_RGCCA],
             set_labels=('MOFA', 'MixOmics', 'RGCCA'),
             set_colors=('skyblue', 'lightgreen', 'lightcoral'),
             alpha=0.6)

# Add a border to the circles
venn3_circles([set_MOFA, set_MixOmics, set_RGCCA], linestyle='dashed')

# Annotate each section with the actual names (if needed)
for idx, subset in enumerate(venn.subset_labels):
    if subset:  # Only annotate non-empty subsets
        subset.set_fontsize(10)


# Display the diagram
plt.title('Venn Diagram top 50 features (candidate biomarkers) Proteomics: MOFA vs MixOmics vs RGCCA')
plt.show()

# %%
import matplotlib.pyplot as plt
from matplotlib_venn import venn3, venn3_circles

# New lists
MOFA = [
    "KIF2C", "AAED1", "ADAMTS2", "ADCY10", "ADPRH", "AGAP2-AS1", "AGBL5", "AKTIP",
    "ALPK2", "AMPD2", "AMZ2P1", "ANGPTL1", "ANK2", "ANKRD20A9P", "APOB", "APOL6",
    "APOM", "ARF4", "ARL4A", "ASB15", "ATG9B", "AXL", "B3GNT9", "BCAM", "BCAN",
    "BNC2", "BRE", "BRIX1", "BTBD19", "C19orf71", "C19orf83", "C3", "C9orf117",
    "C9orf152", "CACNA1E", "CATIP", "CCDC108", "CCDC39", "CCNL1", "CD3EAP",
    "CEBPZOS", "CENPT", "CIT", "COL11A2", "COL1A1", "COL27A1", "COL5A1", "COL7A1",
    "CSMD2", "CSNK1D", "CTDSPL2", "CXADR", "CYP2F1", "DCHS2", "DGKE", "DIMT1",
    "DMTF1", "DNAH8", "DNAJB2", "DOCK6", "DPCR1", "DSCAM", "DSCAML1", "DTNA",
    "DTX1", "EPB41L1", "EYS", "FAM126B", "FBN3", "FCHSD1", "FIGNL1", "FLJ22184",
    "FLJ26850", "FLJ45079", "FLT1", "FOSB", "FOXP4", "FPR3", "FRAS1", "GABARAPL1",
    "GALM", "GAPDHS", "GDPD2", "GNB3", "GPR112", "GPR22", "GPR98", "GSG1L",
    "GUF1", "HIF3A", "HIPK1", "HIPK1-AS1", "HMCN1", "HMCN2", "HOXA-AS3", "HSPB6",
    "HYDIN", "IDI2-AS1", "IER5", "IGSF9", "IL21R", "INSIG1", "IP6K1", "IQGAP3",
    "ITGB2", "ITPKB-IT1", "JMJD6", "JUN", "KAZN", "KCNA3", "KCNC3", "KCNH4",
    "KCNMA1", "KCNQ3", "KHNYN", "KMT2E-AS1", "KRI1", "KSR2", "LAMA5", "LEO1",
    "LINC-PINT", "LINC00880", "LINC01353", "LINC01366", "LMOD2", "LOC100130357",
    "LOC100130476", "LOC100131257", "LOC100131635", "LOC100133445", "LOC100288181",
    "LOC100506499", "LOC100507217", "LOC101927631", "LOC101928062", "LOC101928068",
    "LOC101928363", "LOC101929718", "LOC102724814", "LOH12CR1", "LRIF1", "LRRC39",
    "MAGI2", "MAP1LC3B2", "MAP3K14-AS1", "MASTL", "MED29", "MIR1279", "MIR133A1HG",
    "MIR623", "MKNK1-AS1", "MTFP1", "MUC16", "MUC17", "MUC19", "MUC2", "MUC3A",
    "MUC4", "MYADM", "MYH7", "NAV2", "NFKB2", "NOS1", "NOTCH4", "NRXN3", "NSMAF",
    "NSUN4", "NTRK2", "OSM", "OTOF", "PBXIP1", "PCLO", "PCYOX1", "PDCD4-AS1",
    "PIK3IP1", "PIK3R2", "PLEKHG5", "POLR2E", "PRDM16", "PRKAG2-AS1", "PSIP1",
    "PSMA3", "RANBP1", "RARA-AS1", "RASA1", "REL", "RINT1", "RNF157-AS1",
    "SATB2", "SDCBP", "SGK1", "SH3D19", "SHANK1", "SHANK2", "SHISA7", "SHISA9",
    "SLC15A4", "SLC1A2", "SLC26A9", "SLC29A2", "SLC43A3", "SLC5A2", "SLIT3",
    "SMNDC1", "SNX17", "SPAG1", "SPAG5-AS1", "SPEG", "SPNS2", "SRSF11", "SSC5D",
    "STARD4", "STAT4", "TAGLN2", "TCF7", "TCOF1", "TCP11L2", "TCTEX1D4", "TENM2",
    "TENM4", "TET1", "TGIF1", "TICRR", "TMED9", "TMEM243", "TMEM43", "TMEM52B",
    "TMEM66", "TNS4", "TOM1", "TOM1L2", "TPCN2", "TRDMT1", "TSG101", "TTC25",
    "TULP2", "UNC13A", "USP21", "VPS13A-AS1", "VPS9D1-AS1", "WDR35", "WNK2",
    "ZAN", "ZBTB44", "ZFC3H1", "ZNF165", "ZNF295-AS1", "ZNF573", "ZNF706", "ZSWIM4"
]



MixOmics = [
    'PGM1', 'POLR2B', 'GNPDA2', 'IGFBP7-AS1', 'S100A9', 'HIST1H1D', 'CPSF7',
    'SPIDR', 'MIR4253', 'CEBPD', 'ANXA4', 'MPPE1', 'FAM32A', 'SAC3D1', 'THBS2',
    'CCL4', 'RPL13', 'CNKSR2', 'FGFBP2', 'GNG12-AS1', 'FCN1', 'SLC6A20', 'RPL27A',
    'LOC101928290', 'EEF1G', 'CD69', 'MYSM1', 'CTSS', 'RPL26', 'RPL23', 'NCR3',
    'ST8SIA6-AS1', 'RPL36', 'CNPY3', 'RPPH1', 'NCAM1', 'FURIN', 'TMED11P', 'ARPC5',
    'TANC1', 'NRROS', 'EXOC4', 'RPL19', 'FKBP5', 'CEP290', 'TM9SF1', 'SNX8', 'KIF1C',
    'CIPC', 'SCMH1', 'LRRC24', 'ATG16L2', 'RAI1', 'PIP5K1P1', 'NGEF', 'LCAT', 'MPPED2',
    'MYH7B', 'DDX56', 'GALR2', 'DNAH17', 'LDB3', 'EMC6', 'NAV2-AS2', 'FLJ26850',
    'BCAR3', 'FAM184B', 'C5orf56', 'PDCD4-AS1', 'PRAP1', 'MIR647', 'C15orf57', 'MCEMP1',
    'NIPAL4', 'GPS2', 'LOC102724246', 'VPS37C', 'AVPR2', 'LRRC57', 'MGC34796',
    'LOC389906', 'ATP6AP2', 'IGFALS', 'PASK', 'LPPR3', 'RRP1', 'FTX', 'BTBD19',
    'ATG9B', 'KBTBD12', 'FMNL3', 'TOPORS-AS1', 'SLC39A4', 'LOC100287098', 'CLCF1',
    'PBLD', 'ENTPD1', 'PRKX-AS1', 'PTPRK', 'DNHD1', 'TMPRSS6', 'CSNK1G2-AS1',
    'COL8A2', 'MKL1', 'LOC101927550', 'TMEM108', 'DPYSL4', 'SRP19', 'RADIL',
    'HTATSF1P2', 'LOC100506801', 'PLA2G10', 'PP7080', 'EXOSC1', 'IER5L', 'KRTAP5-2',
    'AHNAK2', 'CCR9', 'LOC100289019', 'ANO7', 'ZFX-AS1', 'CAMSAP3', 'FLJ12825',
    'RAD51', 'LINC00649', 'GPS1', 'ASH1L-AS1', 'TNFAIP8L1', 'RYR2', 'PGAM2',
    'KLHL22', 'RPS6KA2-AS1', 'LOC339666', 'MIR210HG', 'MDK', 'C9orf173', 'CHGA',
    'FAM83G', 'MIR199A1', 'LOC100288162', 'GNG13', 'AMZ1', 'ITGB8', 'C21orf2',
    'SMPD2', 'CELSR1', 'OLFM2', 'NFRKB', 'RMND5B', 'FAM160B2', 'CYP11B1',
    'TMEM220', 'C19orf35', 'ZFHX3', 'FAM185A', 'LOC101928604', 'RFPL3', 'RAB6B',
    'LOC101927069', 'RECQL4', 'PDLIM2', 'MUC5B', 'FAM222B', 'AATK', 'GPR152',
    'PPP1R16A', 'TSEN54', 'ZNF295-AS1', 'RBFOX3', 'VPS9D1', 'LHFPL4', 'LINC00854',
    'ARHGAP39', 'HIPK1-AS1', 'PLIN4', 'JPH4', 'LOC101927497', 'ZSWIM4', 'TFPT',
    'LINC00152', 'RRNAD1', 'LINC01271', 'CDHR5', 'MRPL23-AS1', 'B3GNT5', 'CEMP1',
    'PHKG2', 'SLC25A19', 'TCOF1', 'ADORA2A-AS1', 'PTOV1', 'HRNR', 'POU5F1',
    'C19orf26', 'APC2', 'SLC6A8', 'CPNE5', 'LINC00163', 'PCDH12', 'DDX11L5',
    'TMEM184A', 'LOC286059', 'ITIH3', 'SRGAP1', 'HCFC1-AS1', 'LINC00346',
    'MIR600HG', 'MUC6', 'FBXO6', 'HP09053', 'FAM132A', 'DEXI', 'ADAMTS13',
    'BRAT1', 'CUL9', 'CYP2W1', 'CSNK1D', 'CARD14', 'KANTR', 'ZNF865', 'TRIP10',
    'ATP2C2', 'PEX6', 'ARL17A', 'CLECL1', 'PSD', 'LOC100507156', 'SLC25A12',
    'LOC100289580', 'LOC401052', 'ZBTB46', 'HPDL', 'CNNM3', 'NAT8', 'MYO5C',
    'MRGPRD', 'RFX1', 'KDM8', 'MRPL40', 'ADORA2B', 'ICMT', 'HLA-H', 'CXorf36',
    'TSIX', 'TMEM150C', 'PIN4', 'TMEM176B', 'HP09025', 'ENTPD3', 'POM121L10P'
]





RGCCA = [
    "KMT2C", "AKAP13", "SPEN", "SRRM2", "ATM", "SON", "RNF213", "ANKRD11",
    "FTL", "ARHGEF1", "ASH1L", "KMT2A", "CD74", "PRRC2A", "VCL", "MYL6",
    "ZNF609", "NSD1", "PCNT", "GIT2", "PAG1", "MYO9B", "IKZF3", "SYNE2",
    "ITGAL", "PLEC", "SPTAN1", "ABCA2", "RAB11FIP4", "PRKD2", "UTRN", "NLRC5",
    "HECTD4", "NLRP1", "ESYT1", "SYMPK", "DNAH1", "NIPBL", "JAK3", "RUFY1",
    "AKNA", "FLNA", "SYNE1", "BPTF", "PREX1", "MYCBP2", "FRMD4B", "TYK2",
    "CELF1", "SHKBP1", "DGKD", "UBTF", "PI4KA", "MALAT1", "SUGP2", "THBS1",
    "GAPDH", "ZAP70", "RPS11", "MOB3A", "FNBP4", "PYHIN1", "MADD", "UNC13D",
    "VPS39", "ZBTB40", "NADSYN1", "CCL5", "GPI", "MLXIP", "EPG5", "ZNFX1",
    "NISCH", "MAST3", "ELF4", "VPS13D", "RAP1GAP2", "NXF1", "UBR4", "SUPT6H",
    "TRRAP", "EIF4G3", "SIK3", "CHD3", "CLIP1", "SSH2", "CCNL2", "BRD1",
    "ZNF318", "PRRC2B", "MACF1", "EZH1", "LRBA", "MYO5A", "ZZEF1", "KLF12",
    "GATAD2A", "GCN1L1", "DDX17", "SRCAP", "STAT3", "NUMA1", "C10orf12",
    "TLN1", "MBP", "CDK12", "CCDC88C", "AFF1", "ZCCHC6", "SETD5", "RPL7A",
    "SMG1", "PRKCA", "PARP14", "TUBB1", "CCDC88B", "MAP4", "ARHGDIA", "TET3",
    "NBEAL2", "CALCOCO1", "NCOR2", "GLTSCR1L", "MPRIP", "INPP4A", "GNL3L",
    "SNRNP200", "IKZF1", "CYFIP2", "SNX19", "CYTH1", "GRK6", "ALMS1", "GNAS",
    "KDM5C", "ZNF292", "TRIM38", "ABCC1", "KLC1", "PTPRA", "TAOK3", "SH3BP2",
    "AP1B1", "FMNL1", "EHBP1L1", "RBM33", "PLEKHG3", "GMIP", "ARID1B",
    "BSDC1", "ZBTB7A", "ESYT2", "SORL1", "TMEM131", "DOCK10", "OGT", "CHD2",
    "HNRNPU", "GRIPAP1", "ABCA7", "AFF3", "AES", "DNMT1", "ATP8B2", "ARHGAP17",
    "NOTCH2NL", "IL2RG", "UBA52", "STAT2", "VPS8", "ARRB1", "MAP1A", "DENND5A",
    "RNPEPL1", "PKN1", "DNM2", "STK10", "RPS6KA1", "SERPINB1", "PTBP1", "PSD4",
    "PLCG1", "CIC", "PACS1", "RNF216", "ADAR", "CD84", "ARHGAP4", "SETD1B",
    "CHD7", "SP100", "ARHGAP25", "AAK1", "CD4", "ZFYVE26", "PHF2", "AKT2",
    "TRIP12", "CAPN2", "KIF21B", "RBM19", "ATG2A", "INTS1", "ANKRD44", "ZXDC",
    "LRP1", "GAPVD1", "ATP2A3", "RASSF5", "MYO1F", "KDM2A", "ACAP3", "HNRNPM",
    "PFKL", "NIN", "SMC1A", "GNB2L1", "SH2D3C", "CD6", "ZC3H7B", "ARHGEF2",
    "LARP1", "HDAC6", "PLCB2", "IQSEC1", "MYO18A", "TCERG1", "CABIN1",
    "FAM102A", "DIAPH1", "PRRC2C", "UBR2", "IFI16", "TCIRG1", "ILF3",
    "ARID1A", "INPPL1", "LCK", "AP2B1", "HERC2", "JAK1", "SP140L", "RASA3",
    "CDK5RAP2", "GAK", "PARP4", "MYH9", "PRDM2", "MYL12B","PCNXL2"
]




# Convert lists to sets
set_MOFA = set(MOFA)
set_MixOmics = set(MixOmics)
set_RGCCA = set(RGCCA)

# Create a Venn diagram
plt.figure(figsize=(12,10))
venn = venn3([set_MOFA, set_MixOmics, set_RGCCA],
             set_labels=('MOFA', 'MixOmics', 'RGCCA'),
             set_colors=('skyblue', 'lightgreen', 'lightcoral'),
             alpha=0.6)

# Add a border to the circles
venn3_circles([set_MOFA, set_MixOmics, set_RGCCA], linestyle='dashed')

# Annotate each section with the actual names (if needed)
for idx, subset in enumerate(venn.subset_labels):
    if subset:  # Only annotate non-empty subsets

        subset.set_fontsize(10)


# Display the diagram
plt.title('Venn Diagram top 250 features (candidate biomarkers) Transcriptomics: MOFA vs MixOmics vs RGCCA')
plt.show()

# %%
import matplotlib.pyplot as plt
from matplotlib_venn import venn3, venn3_circles

# Lists renamed as MOFA, Single-Omics, and RGCCA
MOFA = [
    "pHILIC_742.5724_5.1", "pHILIC_247.1437_5.3", "pHILIC_290.1594_11",
    "nRPLC_285.2071_9.2", "nRPLC_512.2683_10.8", "nRPLC_243.1601_8",
    "nHILIC_191.0561_8.5", "nRPLC_567.3173_8.9", "nRPLC_299.2228_9.6",
    "pHILIC_175.1188_15.1", "nHILIC_512.2684_5.7", "nRPLC_163.0765_7.4",
    "nHILIC_163.04_1.4", "nRPLC_489.3582_11", "pHILIC_732.5525_5.1",
    "pHILIC_337.1234_11.6", "nHILIC_87.0087_4.4", "nRPLC_561.4141_11.5",
    "nRPLC_489.3582_10.6", "nRPLC_243.1601_7.9", "nRPLC_413.2004_8.9",
    "nRPLC_487.342_10.8", "pHILIC_299.1383_7.5", "nRPLC_449.364_11.6",
    "nHILIC_181.0367_6.8", "pHILIC_768.5558_3.5", "nRPLC_473.3632_11.4",
    "pRPLC_520.3396_9.8", "pHILIC_350.1185_11.5", "nRPLC_471.3474_11.3",
    "nRPLC_399.3268_11.1", "nRPLC_215.1288_6.8", "nRPLC_369.1741_9.5",
    "nRPLC_393.3013_10.7", "nRPLC_453.3221_10.1", "nRPLC_209.0819_5.9",
    "nHILIC_512.2684_5.7", "nRPLC_461.3269_10.7", "nRPLC_393.3013_10.7",
    "nRPLC_463.3428_11", "nRPLC_229.1445_7.4", "nRPLC_445.3323_11",
    "nRPLC_441.395_11.2", "nRPLC_187.134_7.5", "nRPLC_435.3115_10.4",
    "nRPLC_507.3686_10.6", "nHILIC_441.1596_3.7", "pRPLC_506.3601_10.4",
    "nRPLC_391.2856_9.5", "pHILIC_224.1653_12.6", "pHILIC_161.1283_16.4",
    "pHILIC_161.1283_16.4", "nRPLC_433.3322_11.2"
]




MixOmics = [
    "nRPLC_343.2853_9.8", "nHILIC_144.0302_7.2", "nRPLC_165.0556_2.3",
    "pRPLC_244.1544_1.7", "nRPLC_315.2539_9.7", "pHILIC_114.0661_2.5",
    "nRPLC_188.0352_3.1", "pHILIC_257.1127_2", "pHILIC_171.0763_7.5",
    "nRPLC_204.0665_3", "nRPLC_255.1603_8.1", "nRPLC_153.0193_2.1",
    "nHILIC_144.0666_5.1", "pHILIC_203.0813_7.2", "nRPLC_187.134_7.5",
    "nRPLC_257.176_8.5", "nHILIC_116.0352_7.5", "nHILIC_191.0197_11.2",
    "pHILIC_221.0918_7.5", "nRPLC_311.223_9.8", "pRPLC_445.2947_10.3",
    "pHILIC_237.0865_7.3", "nHILIC_204.0665_5.1", "pHILIC_189.1596_18.3",
    "nRPLC_333.2073_7.6", "pHILIC_229.1544_10.4", "nRPLC_213.1497_8.1",
    "nRPLC_331.1762_7.2", "nHILIC_133.0142_10.4", "nRPLC_433.3323_10.5",
    "pHILIC_170.0923_8.5", "nHILIC_132.0302_8.3", "nRPLC_315.2541_9.4",
    "nHILIC_333.0592_10.7", "nRPLC_201.1133_5.9", "nHILIC_181.0506_6.2",
    "nHILIC_168.0778_10.2", "nRPLC_215.1653_8.4", "nHILIC_165.0404_7.8",
    "nRPLC_597.3048_11.9", "nHILIC_147.0297_10.2", "nRPLC_131.0714_1.6",
    "nRPLC_465.249_8.3", "pRPLC_146.06_3", "nRPLC_371.189_9.7",
    "nHILIC_235.0723_6.5", "nRPLC_209.1184_8.2", "nHILIC_188.0023_1.6",
    "pRPLC_246.17_1.9", "pHILIC_157.0607_8.3"
]

RGCCA = [
    "nRPLC_321.2435_10.1", "nRPLC_305.2486_10.7", "nRPLC_333.2799_11.2",
    "nRPLC_319.2278_10", "nRPLC_295.2278_9.9", "nRPLC_271.228_10.3",
    "nRPLC_359.2957_11.5", "nRPLC_267.1966_9.2", "nRPLC_297.2799_11.7",
    "nRPLC_295.2642_11.1", "nRPLC_213.1498_7.8", "nRPLC_329.2487_10.7",
    "nRPLC_357.2801_11.2", "nRPLC_243.1965_9.3", "nRPLC_331.2644_10.9",
    "nRPLC_293.2123_9.6", "nRPLC_293.2122_9.9", "nRPLC_309.2801_11.4",
    "nRPLC_215.1653_8.4", "nRPLC_187.1339_7.1", "nRPLC_307.2644_11",
    "nRPLC_183.139_8.5", "pRPLC_675.5429_12.6", "nRPLC_211.1704_9.4",
    "nRPLC_241.181_9", "nRPLC_249.1859_9.8", "nRPLC_197.1547_9.1",
    "nRPLC_239.2016_10.1", "nRPLC_225.186_10", "nRPLC_335.2957_11.7",
    "nRPLC_297.2436_10", "nRPLC_241.1809_8.8", "nRPLC_239.1653_8.5",
    "nRPLC_609.5098_10.5", "nRPLC_213.1497_8.1", "pRPLC_369.2397_10.5",
    "nRPLC_667.5325_10.5", "pRPLC_510.3913_10.9", "pRPLC_359.3154_11",
    "nRPLC_265.2171_10.3", "nRPLC_209.1184_8.2", "nRPLC_723.5955_11",
    "nRPLC_251.2016_10", "nRPLC_297.2435_10.2", "nRPLC_227.1288_7.1",
    "nRPLC_267.233_10.6", "nRPLC_169.1233_8.2", "pRPLC_524.3708_10.6",
    "pRPLC_647.5116_11.7", "nRPLC_312.2546_10.4"
]



# Convert lists to sets
set_MOFA = set(MOFA)
set_MixOmics = set(MixOmics)
set_RGCCA = set(RGCCA)

# Create a Venn diagram
plt.figure(figsize=(12,10))
venn = venn3([set_MOFA, set_MixOmics, set_RGCCA],
             set_labels=('MOFA', 'MixOmics', 'RGCCA'),
             set_colors=('skyblue', 'lightgreen', 'lightcoral'),
             alpha=0.6)

# Add a border to the circles
venn3_circles([set_MOFA, set_MixOmics, set_RGCCA], linestyle='dashed')

# Annotate each section with the actual names (if needed)
for idx, subset in enumerate(venn.subset_labels):
    if subset:  # Only annotate non-empty subsets
        subset.set_fontsize(10)


# Display the diagram
plt.title('Venn Diagram top 50 features (candidate biomarkers) Metabolomics: MOFA vs MixOmics vs RGCCA')
plt.show()
